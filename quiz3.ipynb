# %%
import os
os.getcwd(), os.listdir()
# Out:
# ('C:\\Users\\Cemre',
#  ['.android',
#   '.AndroidStudio3.3',
#   '.AndroidStudio4.0',
#   '.atom',
#   '.config',
#   '.dotnet',
#   '.eclipse',
#   '.gitconfig',
#   '.gradle',
#   '.idlerc',
#   '.ipynb_checkpoints',
#   '.ipython',
#   '.jupyter',
#   '.librarymanager',
#   '.m2',
#   '.matplotlib',
#   '.nuget',
#   '.p2',
#   '.PyCharmCE2018.3',
#   '.RapidMiner',
#   '.sts4',
#   '.templateengine',
#   '.tooling',
#   '.VirtualBox',
#   '15983486-canakkale-canakkale.jpg',
#   '3D Objects',
#   'anaconda3',
#   'AndroidStudio',
#   'AndroidStudioProjects',
#   'ansel',
#   'AppData',
#   'Application Data',
#   'Autodesk',
#   'Belgelerim',
#   'BilimselHesaplama',
#   'canakkale_kilitbahir.jpg',
#   'Contacts',
#   'Cookies',
#   'debug.log',
#   'Desktop',
#   'Documents',
#   'Downloads',
#   'eclipse',
#   'eclipse-workspace',
#   'Favorites',
#   'Image_Processing',
#   'Intel',
#   'IntelGraphicsProfiles',
#   'java_error_in_pycharm_13900.log',
#   'java_error_in_pycharm_296.log',
#   'java_error_in_pycharm_3764.log',
#   'kanal-canakkale.jpg',
#   'Links',
#   'Local Settings',
#   'MicrosoftEdgeBackups',
#   'Music',
#   'NetHood',
#   'NTUSER.DAT',
#   'ntuser.dat.LOG1',
#   'ntuser.dat.LOG2',
#   'NTUSER.DAT{dc059507-a426-11ea-8d0b-81650c5643f6}.TM.blf',
#   'NTUSER.DAT{dc059507-a426-11ea-8d0b-81650c5643f6}.TMContainer00000000000000000001.regtrans-ms',
#   'NTUSER.DAT{dc059507-a426-11ea-8d0b-81650c5643f6}.TMContainer00000000000000000002.regtrans-ms',
#   'ntuser.ini',
#   'OneDrive',
#   'opera autoupdate',
#   'Pictures',
#   'Postman',
#   'PrintHood',
#   'ProgramlamaLab',
#   'PycharmProjects',
#   'quiz3.ipynb',
#   'RazorPagesApartmanYonetimiContext-b915623f-e393-4ac9-a6de-e3c926b3e497.mdf',
#   'RazorPagesApartmanYonetimiContext-b915623f-e393-4ac9-a6de-e3c926b3e497_log.ldf',
#   'Recent',
#   'Roaming',
#   'Saved Games',
#   'Searches',
#   'SendTo',
#   'source',
#   'Start Menu',
#   'Templates',
#   'untitled',
#   'Untitled.ipynb',
#   'Untitled1.ipynb',
#   'Untitled2.ipynb',
#   'Videos',
#   'VirtualBox VMs',
#   'vizedenSonra',
#   'wekafiles',
#   'Yeni klasör',
#   'Yeni klasör (2)',
#   'Yeni klasör (3)',
#   'Yeni klasör (4)'])

# %%
path = r"C:\Users\Cemre\Image_Processing"
file_name_with_path = path + "\lena.jpg"
file_name_with_path
# Out:
# 'C:\\Users\\Cemre\\Image_Processing\\lena.jpg'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img_0 = plt.imread(file_name_with_path)
# %matplotlib inline
plt.imshow(img_0)
plt.show()

# %%
np.min(img_0), np.max(img_0)
# Out:
# (0, 255)

# %%
img_0.ndim, img_0.shape
# Out:
# (3, (225, 225, 3))

# %%
img_0.ndim, img_0.shape
# Out:
# (3, (225, 225, 3))

# %%
def convert_rgb_to_gray(im_1):
    m = im_1.shape[0]
    n = im_1.shape[1]
    im_2=np.zeros((m,n)) #dtype='uint8'
    for i in range (m):
        for j in range(n):
            im_2[i,j] = get_distance(im_1[i,j,:])
    return im_2

def get_distance(v,w=[1/3,1/3,1/3]):
    a, b, c = v[0], v[1], v[2]
    w1, w2, w3 = w[0], w[1], w[2]
    d = ((a**2)*w1+(b**2)*w2+(c**2)*w3)**.5
    return d

# %%
def my_f_1(a,b):
    assert a>=0; " intensity pozitive", "error insensity not positive"
    if(a<=255-b):
        return a + b
    else:
        return 255
    
my_f_1(243,30)
# Out:
# 255

# %%
def my_f_2(a):
   # assert a>=0; " intensity pozitive", "error insensity not positive"
        return int(255-a)
    
my_f_2(243)
# Out:
# 12

# %%
img_1 = convert_rgb_to_gray(img_0)
plt.imshow(img_1, cmap= 'gray')
plt.show()

# %%
m,n = img_1.shape
img_2=np.zeros((m,n),dtype='uint8')

# %%
for i in range (m):
        for j in range(n):
            #intensity = img_1[i,j]
            #increment = 70
            ## print(intensity)
            #img_2[i,j] = my_f_1(intensity,increment)
            intensity = img_1[i,j]
            img_2[i,j] = my_f_2(intensity)

# %%
plt.subplot(1,2,1),plt.imshow(img_1, cmap= 'gray')
plt.subplot(1,2,2),plt.imshow(img_2, cmap= 'gray')
plt.show()

# %%
plt.subplot(2,2,1),plt.imshow(img_0, cmap='gray')
plt.subplot(2,2,2),plt.imshow(img_1, cmap='gray')
plt.subplot(2,2,3),plt.imshow(img_2, cmap='gray')
plt.show()

# %%
np.min(img_2),np.max(img_2)
# Out:
# (15, 220)

# %%
x=np.array(list(range(100)))
y1=np.power(x/float(np.max(x)),1)
y2=np.power(x/float(np.max(x)),10)
y3=np.power(x/float(np.max(x)),1/10)

#y=1/(1+np.exp(x))
#y=np.sin(np.array(list(range(100))))
#y=np.array(list(range(100)))

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
x=img_0
img_100=np.power(x/float(np.max(x)),10)
plt.imshow(img_100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
